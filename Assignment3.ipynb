# %%
import numpy as np

X = np.array([1, -1, 2, 4, -3, 5, -2, 3, -1, 4, 5, 2, -7, 4, -3])
mean = np.mean(X)
variance = np.var(X)

print("Mean: ", mean)
print("Variance: ", variance)
# Out:
# Mean:  0.8666666666666667
# Variance:  11.84888888888889
